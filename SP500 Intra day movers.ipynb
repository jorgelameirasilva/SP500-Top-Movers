# %%
import yfinance as yf
import pandas as pd
import requests

# %%
url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"

# %%
sp500_tickers = pd.read_html(url)

# %%
tickers = sp500_tickers[0]

# %%
tickers
# Out:
#     Symbol             Security SEC filings             GICS Sector  \
# 0      MMM           3M Company     reports             Industrials
# 1      ABT  Abbott Laboratories     reports             Health Care
# 2     ABBV          AbbVie Inc.     reports             Health Care
# 3     ABMD          ABIOMED Inc     reports             Health Care
# 4      ACN        Accenture plc     reports  Information Technology
# ..     ...                  ...         ...                     ...
# 500    YUM      Yum! Brands Inc     reports  Consumer Discretionary
# 501   ZBRA   Zebra Technologies     reports  Information Technology
# 502    ZBH        Zimmer Biomet     reports             Health Care
# 503   ZION        Zions Bancorp     reports              Financials
# 504    ZTS               Zoetis     reports             Health Care
#
#                       GICS Sub-Industry     Headquarters Location  \
# 0              Industrial Conglomerates       St. Paul, Minnesota
# ...

# %%
main_df = pd.DataFrame(columns=["Ticker", "Movement"])

for ticker in tickers["Symbol"]:
    df = yf.download(ticker, period="5d")
    movement = (df["High"] - df["Low"]) / df["Low"]
    movement = movement.mean()
    main_df = main_df.append({"Ticker":ticker, "Movement":movement}, ignore_index=True)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
main_df.dropna(inplace=True)

# %%
biggest_movers = main_df.sort_values(by="Movement",ascending=False).head(10)

# %%
biggest_movers
# Out:
#     Ticker  Movement
# 294   LUMN  0.173736
# 258    IRM  0.130139
# 471   VIAC  0.130118
# 28     AAL  0.127031
# 144  DISCA  0.112088
# 276     KR  0.109537
# 166   ENPH  0.105751
# 277     LB  0.104718
# 201   FOXA  0.103418
# 407    STX  0.083699

# %%
additional_data = tickers[["Symbol", "Security", "GICS Sector"]]

# %%
additional_data
# Out:
#     Symbol             Security             GICS Sector
# 0      MMM           3M Company             Industrials
# 1      ABT  Abbott Laboratories             Health Care
# 2     ABBV          AbbVie Inc.             Health Care
# 3     ABMD          ABIOMED Inc             Health Care
# 4      ACN        Accenture plc  Information Technology
# ..     ...                  ...                     ...
# 500    YUM      Yum! Brands Inc  Consumer Discretionary
# 501   ZBRA   Zebra Technologies  Information Technology
# 502    ZBH        Zimmer Biomet             Health Care
# 503   ZION        Zions Bancorp              Financials
# 504    ZTS               Zoetis             Health Care
#
# [505 rows x 3 columns]

# %%
final_df = biggest_movers.merge(additional_data, left_on="Ticker", right_on="Symbol")

# %%
final_df.drop("Symbol", axis=1, inplace=True)

# %%
final_df
# Out:
#   Ticker  Movement                    Security             GICS Sector
# 0   LUMN  0.173736          Lumen Technologies  Communication Services
# 1    IRM  0.130139  Iron Mountain Incorporated             Real Estate
# 2   VIAC  0.130118                   ViacomCBS  Communication Services
# 3    AAL  0.127031     American Airlines Group             Industrials
# 4  DISCA  0.112088  Discovery, Inc. (Series A)  Communication Services
# 5     KR  0.109537                  Kroger Co.        Consumer Staples
# 6   ENPH  0.105751              Enphase Energy  Information Technology
# 7     LB  0.104718               L Brands Inc.  Consumer Discretionary
# 8   FOXA  0.103418   Fox Corporation (Class A)  Communication Services
# 9    STX  0.083699          Seagate Technology  Information Technology

# %%
import plotly.express as px

# %%
fig = px.scatter(final_df, x="GICS Sector", y="Ticker", 
                 size="Movement", color="")
